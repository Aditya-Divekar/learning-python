# %%
# number data type

# %%
number = 12
type(number)
# Out:
# int

# %%
print(number)
# Out:
# 12

# %%
num2 = 15.5
type(num2)
# Out:
# float

# %%
num3 = 5e3
num3
# Out:
# 5000.0

# %%
num4 = 4+5j
type(num4)
# Out:
# complex

# %%
# abs function 
#abs is inbulid function is can converted negative vaues into positive

# %%
round(4.8)
# Out:
# 5

# %%
round(4.5)
# Out:
# 4

# %%
min(3,5,7,9,1,4,)
# Out:
# 1

# %%
max( 5476,479870,467,787)
# Out:
# 479870

# %%
num =15 
isinstance(num,int)  #istance its check the data type of particular task
# Out:
# True

# %%
# evat function 
# its can use directly expression from the users

# %%
a= eval(input("enter the expression = "))
# Out:
# enter the expression =  65

# %%
a
# Out:
# 65

# %%
# exchanging the values of two variables

# %%
a = 12

# %%
b=a

# %%
b
# Out:
# 12

# %%
# tot two method
# swaping without using variables

# %%
x = 10 
y = 20
x,y=y,x

# %%
x
# Out:
# 20

# %%
y
# Out:
# 10

# %%
#swaping with using third variables

# %%
a = 100
b = 200

# %%
temp = a
a=b
b=temp

# %%
c=a
a=b
b=c

# %%
a
# Out:
# 100

# %%
b
# Out:
# 200

# %%
c
# Out:
# 200

# %%
a= 5.5/5

# %%
a
# Out:
# 1.1

# %%
5//2
# Out:
# 2

# %%
4%2
# Out:
# 0

# %%
11%5
# Out:
# 1

# %%
# math module

# in python a mosule is simply a file thats contain python code
# functuon ,variables,clases,method which u can store in the file and u can used in other programms
# the math module is a built in  pyhton module 
# it is used for mathematical calculation

# %%
# Why use the math module?

# To perform advanced mathematical operations
# Provides faster and accurate calculations
# Useful in data analysis, AI/ML, engineering, and scientific programs

# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.remainder(5,2)
# Out:
# 1.0

# %%
math.factorial(5)
# Out:
# 120

# %%
math.log(1)
# Out:
# 0.0

# %%
math.ceil(4.1)
# Out:
# 5

# %%
math.floor(4.8)
# Out:
# 4

# %%
math.cos(0)
# Out:
# 1.0

# %%
# random number
# it is used in gaming , tasting ,stimulation and security purpose

# %%
# import random module
import random

# %%
# 1) random method
# genereted the random numbers from 0 to 1

# %%
random.random()
# Out:
# 0.03370151582309622

# %%
# 2) randint() method
# its generated random integer between given range

# %%
random.randint(1,10)
# Out:
# 10

# %%
dice= random.randint(1,6)

# %%
dice
# Out:
# 2

# %%
# 3) randrange method

# %%
random.randrange(1,20,2)
# Out:
# 5

# %%
# 4) choice () method
# select random item from lists

# %%
fruits=["apple","banana","papai"]
random.choice(fruits)
# Out:
# 'banana'

# %%
# 5) shuffle() method

# %%
cards= [1,2,3,4,5,6]
random.shuffle(cards)

# %%
cards
# Out:
# [6, 4, 2, 1, 3, 5]

# %%
# seed() method

# %%
random.seed(10)
random.randint(1,100) # its genersted same random number everytime
# Out:
# 74

# %%
# OTP generator

# %%
otp=random.randint(100000,999999) # its give different otp everytime

# %%
otp
# Out:
# 134167

# %%
#Toss Progeram

# %%
toss = random.choice(["Heads","Tails"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 toss = random.choice(["Heads","Tails"])
#
# NameError: name 'random' is not defined

# %%
toss
# Out:
# 'gandit'
