# %% [markdown]
# # Tuple

# %% [raw]
# 1.TAINER DATA TYPE
# 2.CONTAIN MULTIPLE VALUES
# 3.DENOTED BY ()
# 4.SEQUENCE DATATYPE
# 5.IMMUTABLE
# 6.COTAIN DUPLICATE VAL
# 7.ORDER DATATYPE
# 8.HOMOGENEOUS OR HETROGENEOUS

# %%
a = (1,2,3,)

# %%
type(a)
# Out:
# tuple

# %%
# Repetition

# %%
(10,20,30) * 2
# Out:
# (10, 20, 30, 10, 20, 30)

# %%
# Indexing

# %%
a = (10,2,9,68,75,69,69,34,53,543,7)
a[1]
# Out:
# 2

# %%
a[4]
# Out:
# 75

# %%
a[-4]
# Out:
# 34

# %%
for i in (10,2,9,68,75,69,69,34,53,543,7):
    print(i, end = " ")
# Out:
# 10 2 9 68 75 69 69 34 53 543 7

# %%
for i in (10,2,9,68,75,69,69,34,53,543,7):
    if i % 2 == 0:
        print(i,end = " ")
# Out:
# 10 2 68 34

# %%
#  inbuilt fun apply on tuple

# %%
tup1 = (10,2,9,68,75,69,69,34,53,543,7)

# %%
len(tup1)
# Out:
# 11

# %%
max(tup1)
# Out:
# 543

# %%
min(tup1)
# Out:
# 2

# %%
sum(tup1)
# Out:
# 939

# %%
sorted(tup1)
# Out:
# [2, 7, 9, 10, 34, 53, 68, 69, 69, 75, 543]

# %%
sorted(tup1 , reverse = True)
# Out:
# [543, 75, 69, 69, 68, 53, 34, 10, 9, 7, 2]

# %%
# Methods to apply on tuple

# %%
a = (23,65,78,49,35,79,36)

# %%
a.index(23)
# Out:
# 0

# %%
a.count(78)
# Out:
# 1

# %%
a = (100,200,300)

# %%
x,y , z=a

# %%
x
# Out:
# 100

# %%
y
# Out:
# 200

# %%
z
# Out:
# 300

# %%
f= (11,23,(33,44),56)
print(type(f))
# Out:
# <class 'tuple'>

# %%
f[2]
# Out:
# (33, 44)

# %%
e= []
e.append((55,66,77))
e
#  add ele [(55,77,88)]
# Out:
# [(55, 66, 77)]

# %%
lis = []
num = int(input("Enter the no. of stud :"))
for i in range(num):
    name =(input("Enter the name of stud :"))
    roll = int(input("Enter the roll no of stud :"))
    marks = float(input("Enter the marks of stud :"))
    lis.append((name , roll ,marks))
print(lis)
# Out:
# Enter the no. of stud : 2
# Enter the name of stud : adi
# Enter the roll no of stud : 11
# Enter the marks of stud : 99
# Enter the name of stud : pratik
# Enter the roll no of stud : 18
# Enter the marks of stud : 0.9
# [('adi', 11, 99.0), ('pratik', 18, 0.9)]

# %%
lis = []
num = int(input("Enter the no. of stud :"))
for i in range(num):
    name =(input("Enter the name of stud :"))
    roll = int(input("Enter the roll no of stud :"))
    marks = float(input("Enter the marks of stud :"))
    lis.append((name , roll ,marks))
print(lis)
max1 = 0 
for i in lis:
    if i[2]>max1:
        max1 = i[2]
    topper = i[0]
