# %% [markdown]
# # SET

# %% [raw]
# 1.SET IS A CONTAINER DATA TYPE
# 2.DENOTED BY {}
# 3.UNORDERED DATA TYPE
# 4.IT DOSENT SUPPORT INDEXING AND SLICING , THATS WHY IT IS NOT SEQUENCE DATA TYPE

# %%
set1 = set()

# %%
type(set1)
# Out:
# set

# %%
set2 = {4,5,6,7,8,9,2}
set2
# Out:
# {2, 4, 5, 6, 7, 8, 9}

# %%
type(set2)
# Out:
# set

# %%
#  INBUILT SET FUNCTIONS

# %%
set3 = {4,5,6,7,8,9,2}

# %%
max(set3)
# Out:
# 9

# %%
min(set3)
# Out:
# 2

# %%
sorted(set3)
# Out:
# [2, 4, 5, 6, 7, 8, 9]

# %%
sorted(set3 , reverse = True)
# Out:
# [9, 8, 7, 6, 5, 4, 2]

# %%
set3
# Out:
# {2, 4, 5, 6, 7, 8, 9}

# %%
for i in set3:
    print(i)
# Out:
# 2
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#  METHODS APPLY ON SET

# %%
set1 = {2, 4, 5, 6, 7, 8, 9}

# %%
set1.add(44)
set1
# Out:
# {2, 4, 5, 6, 7, 8, 9, 44}

# %%
set1.remove(4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 set1.remove(4)
#       2 set1
#
# KeyError: 4

# %%
set1
# Out:
# {2, 5, 6, 7, 8, 9, 44}

# %%
set1 = {"apple","banana","grapes"}
set2 = {"microsoft", "nokia" ,"apple", "realme"}

# %%
set3 = set1.intersection(set2)

# %%
set3
# Out:
# {'apple'}

# %%
set4 = set1.symmetric_difference(set2)

# %%
set4
# Out:
# {'banana', 'grapes', 'microsoft', 'nokia', 'realme'}

# %%
set1 = {"apple","banana","grapes"}
set2 = {"microsoft", "nokia" ,"apple", "realme"}
set1.update(set2)
set1
# Out:
# {'apple', 'banana', 'grapes', 'microsoft', 'nokia', 'realme'}

# %%
set1.clear()
set1
# Out:
# set()

# %%
set1 = {"apple","banana","grapes"}
set2 = {"microsoft", "nokia" ,"apple", "realme"}

set1.difference(set2)
# Out:
# {'banana', 'grapes'}

# %%
set2.difference(set1)
# Out:
# {'microsoft', 'nokia', 'realme'}

# %%
a = {"x","y"}
b = {"z","y"}
u = a.union(b)

# %%
print(u)
# Out:
# {'y', 'z', 'x'}

# %%
sss
