# %%
# Operatoe
#operator is a symbol its perform some specific task perperomce

# %%
# 1) Arithmatic operation

# %%
# addition
400 + 4000
# Out:
# 4400

# %%
# suntraction
400 - 4000
# Out:
# -3600

# %%
# multiplication
400 * 4000
# Out:
# 1600000

# %%
# division
400 / 4000
# Out:
# 0.1

# %%
# race of operator 
2**3
# Out:
# 8

# %%
# integer division or floor division operator
4//3
# Out:
# 1

# %%
# 2) Relational operator or comparision opretor

# %%
# euql to opretor

# %%
121==121
# Out:
# True

# %%
#  not equl to opretor

# %%
121!=121
# Out:
# False

# %%
#less than

# %%
200<400
# Out:
# True

# %%
# greater than

# %%
200>400
# Out:
# False

# %%
#less than equal to
200<=400
# Out:
# True

# %%
ord("g")
# Out:
# 103

# %%
# logical operator
# and , or,not

# %%
# 1) And 
# it assigns to multiplication
# it is used when both condition should be true

# %%
 50>30 and 30>10
# Out:
# True

# %%
# 2) Or operator
# it assigns to addition 
# it is used when one condition  should be true

# %%
50>30 or 30<10
# Out:
# True

# %%
# not 
# it will convert true into false or viceversa

# %%
True and False
# Out:
# False

# %%
not False
# Out:
# True

# %%
# 4) Assignment operator

# %%
# 1) assign
a = 12
a
# Out:
# 12

# %%
# addition and assign
a= 12
a+=5

# %%
a
# Out:
# 17

# %%
# addition and assign
b=15
a-=5

# %%
b
# Out:
# 15

# %%
# divison and assign
c=20
c/=5

# %%
c
# Out:
# 4.0

# %%
# bitwise oprator
# it perfoemce opreation bit bt bit

# %%
# binary...base2
# hexasecimal....base 16
# octal...base 8
# decimal...base 10

# %%
a= 12
bin(a)
# Out:
# '0b1100'

# %%
oct(a)
# Out:
# '0o14'

# %%
b=0b1100
b
# Out:
# 12

# %%
# & bitwise operatoe

# %%
a =12
b=13
a&b
# Out:
# 12

# %%
# or bitwise operator

# %%
a =12
b=13
a|b
# Out:
# 13

# %%
# ex or bitwise operator 
a =12
b=13
a^b
# Out:
# 1

# %%
# compliment oprator

# %%
~-3
# Out:
# 2

# %%
~+3
# Out:
# -4

# %%
# right shifr bitwise operator
a = 12
a>>2

#1100  → shift 1 → 0110  
#0110  → shift 2 → 0011
#12 >> 2 = 12 / (2²) = 12 / 4 = 3
# Out:
# 3

# %%
# left shifr bitwise operator
a = 12
a<<2

#1100  → shift 1 → 11000  
#11000 → shift 2 → 110000
#12 << 2 = 12 × (2²) = 12 × 4 = 48
# Out:
# 48

# %%
# 6) menbership operatpoe

# %%
# in
20 in [20,30,40,50.70]
# Out:
# True

# %%
# in
15 in [20,30,40,50.70]
# Out:
# False

# %%
# 7) identity operator

# %%
# is
a=12
b=12
a is b
# Out:
# True

# %%
id(a)
# Out:
# 140718374823176

# %%
id(b)
# Out:
# 140718374823176

# %%
x=30
y=30.0
x is y
# Out:
# False

# %%
id(x)
# Out:
# 140718374823752

# %%
id(y)
# Out:
# 2654839339408
