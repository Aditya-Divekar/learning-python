# %% [markdown]
# # STRING

# %%
# it is container data type
# can store muli values
# set or characters of characters 
# string support indexing
# string supports slicing therefore it is called sequence ddatatype
# denotes by '' , "" , ''' '''

# %%
"fortune"
type("fortune")
# Out:
# str

# %%
#concatenatioin 
"fortune" +"cloud" +"pune"
# Out:
# 'fortunecloudpune'

# %%
# Repetiotioin
"fortune"*3
# Out:
# 'fortunefortunefortune'

# %%
print("#" * 50)
print("WELCOME")
print("#" * 50)
# Out:
# ##################################################
# WELCOME
# ##################################################

# %% [markdown]
# # INDEXING

# %%
# each charact in string has its own no. position
# use of indexing to access a given value
# string suppports indexing
# python supports positive as well as negative

# %%
name = "Suraj"
name[3]
# Out:
# 'a'

# %%
name[-2]
# Out:
# 'a'

# %%
email = "amol@2001"
email[4]
# Out:
# '@'

# %% [markdown]
# # SLICING

# %%
# To get a some part of string 
# in slicing end is always exclusive
# syntax 
    #[starrt : end : step] start ,stop, how many steps to jump

# %%
name = 'suraj'
name[1:4:1]
# Out:
# 'ua'

# %%
name[2:4]
# Out:
# 'ra'

# %%
name[::2]
# Out:
# 'srj'

# %%
name[::-2]
# Out:
# 'jrs'

# %%
name[::-1]
# Out:
# 'jarus'

# %%
name[1:4:2]
# Out:
# 'ua'

# %%
date = "08-05-2026"
date[6:]
# Out:
# '2026'

# %%
email = "amol@2026"
email[:4]
# Out:
# 'amol'

# %%
file = "report.pdf"
file[-3:]
# Out:
# 'pdf'

# %%
# Inbuilt functions apply on string
# dir(str)
# help(str)
# dir(_builtins_)

# %%
name = "fortunecloud"
len(name)
# Out:
# 12

# %%
max(name)
# Out:
# 'u'

# %%
min(name)
# Out:
# 'c'

# %%
id(name)
# Out:
# 2193682226928

# %%
# methods to apply on string
# generally methods show in blue in color

# %%
name = "dhonii"
name.upper()
# Out:
# 'DHONII'

# %%
name.count("i")
# Out:
# 2

# %%
# SPLIT method
# spliit is a method to convert givr=en string intp list
name = "Fortune Cloud Tech"
name.split()
# Out:
# ['Fortune', 'Cloud', 'Tech']

# %%
# JOIN
# join is a method to convert given  list into string
