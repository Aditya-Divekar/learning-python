# %%
# Input Function()

# %%
# to take a values from users 
# input function always writen the data as string

# %%
name = input ("enter the Institute Name = ")
# Out:
# enter the Institute Name =  Fortune Cloud

# %%
marks=input("Enter the marks = ")
# Out:
# Enter the marks =  79.45

# %%
# Addition og of two numbers using input function

# %%
num1 = int(input ("enter the num1 = "))
num2 = int(input ("enter the num2 = "))
result =  num1 + num2 
print(result)
# Out:
# enter the num1 =  20
# enter the num2 =  30
# 50

# %%
# take a two value 1 float and one is int 
num1 = int(input ("enter the num1 = "))
num2 = float(input ("enter the num2 = "))
result =  num1 * num2 
print(result)
# Out:
# enter the num1 =  3
# enter the num2 =  5
# 15.0

# %%
# find the area of circle take a radius input from users
r  = int(input ("enter the radius of circle = "))
area = 3.14* r*r
print("ara of a circle=" ,area)
# Out:
# enter the radius of circle =  4
# ara of a circle= 50.24

# %%
# area of tringle 
# area of square 
# area od sphere

# %%
t=int(input("enter the base of triangle"))
t2= int(input("enter the hight of triangle"))
result= 1/2 * t*t2
print(result)
# Out:
# enter the base of triangle 4
# enter the hight of triangle 5
# 10.0

# %%
S=int(input("enter the side of square"))
result = S*S
print(result)
# Out:
# enter the side of square 5
# 25

# %%
r=int(input("enter the number "))
result = 4 *3.14*(r*r)
print(f"area of sphwrw is {result}")
# Out:
# enter the number  5
# area of sphwrw is 314.0

# %%
r=int(input("enter the number "))
result = 4/3 *3.14*(r*r*r)
print(f"volume of sphere is {result}")
# Out:
# enter the number  5
# volume of sphwrw is 523.3333333333334
