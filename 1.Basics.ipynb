# %%
# KEYWORDS
    # 1.keywords are reserve words in python
    # 2.total 35 keywords are in python
    # 3.True , False , None only starts with capital

# %%
# how to show keywords?
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# VARIABLES
  # 1.Global variable
  # 2.Local variable

# %%
# how to define variables in python

    #1.variable can only start with letters and underscore.
    #2.keywords name cant use as variable name
    #3.variable name are case sensitive
    #4.vaiable name cant start with digit

# %%
name = "Fortune Cloud Technology"
print(name)
# Out:
# Fortune Cloud Technology

# %%
# print ()
    # print() is a inbuilt function in python  used to show output
    # generally functions and keyword in python shows in green color

# %%
# Q1 create 3 different variables 1.name 2._num 3.Z

name= "Aditya Divekar"
_num = 21
Z = "Sambhajinagar"
print(name,_num,Z)
# Out:
# Aditya Divekar 21 Sambhajinagar

# %%
# type
# checks the datatype of given variable

# %%
type(name)
# Out:
# str

# %%
type(_num)
# Out:
# int

# %%
# Comment :
    # 1.It leaves the information in your code
    # 2.It is used for documentation purpose
    # 3.It is denoted by #(hashtag)

# %%
# number data type
    # 1.integer
    # 2.float
    # 3.complex

# %%
#1. integer :
    # it is no. data type
    # int is short name of integer
    # it is whole number

#2. float :
    # 1.it contain decimal points

# 3. Complex :
    # 1.it contain real and imaginary part

# 4. Boolean :
    # 1.True
    # 2.False

# %%
#1. integer :
a=10+12j
type(a)

#2. float :
b= 12
type(b)

# 3.Complex :
c= 1.28
type(c)

# 4.Boolean :
e=False
type(e)
# Out:
# bool

# %%
# Data TYpes
    # 1.Container data type
        # Those datatypes which can store multiple values
        # ex. : List , Tuple , Set , Dictionary , Range , Array , String
        
    # 2.non-container data type
         # Those datatypes which can not store multiple values
         # ex. : Integer , Float , Complex , True ,False ,None

# %%
# String

    # container data type
    # set of or collections of characters
    # ex. 
name  = "MIT COLLEGE"
print(name)
type(name)

# %%
# how to show multiliine string in python

'''
hello
good evening
to all
'''

# %%
# List

# 1.Denoted by [square bracket]
# ex. 
list = [1,2,3,4]
print(list)

# %%
# Tuple

# denoted by ()
# ex
tup = (20 ,30 , "AADU" , 30.46)
print(tup)

# %% [markdown]
# # SET

# %%
# Set is a coontainer dtype which contain multiple value 
# denoted by (curly braces)

# %%
set1= {3,4,5,6,7}
print(set1)
type(set1)
# Out:
# {3, 4, 5, 6, 7}
# set

# %% [markdown]
# # DICTIONARY

# %%
# Set is a container dtype which store info in pair of key value pair

# %%
dict = {"name" : "adi" , "Marks" : 99 }
print(dict)
# Out:
# {'name': 'adi', 'Marks': 99}

# %% [markdown]
# # TYPECASTING

# %%
# conversion of one data type into another data type called as type casting

# %%
a = 12
float(a)
# Out:
# 12.0

# %%
complex(a)
# Out:
# (12+0j)

# %%
str(a)
# Out:
# '12'

# %%
na = "fortune"
list(na)
# Out:
# ['f', 'o', 'r', 't', 'u', 'n', 'e']
